# %%
############################### Electron neutrino ######################################################################################################

####################### wire cell #####################################################################################

#####################################################################################################################################

import ROOT
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
import math
import scipy.stats as stats

########################################################################################################################################
##                                  electron neutrino flux
########################################################################################################################################

f_flux = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/MicroBooNE_FluxHist.root","READ")
tree_flux = f_flux.Get("nue")
nue_flux = 0
for i in range(1,150):
    value_bin_flux = tree_flux.GetBinContent(i)
    nue_flux = nue_flux + value_bin_flux
    
print(nue_flux)          # nue_flux is the total electron neutrino flux 

########################### true wire cell cross section per unit mean energy through GIBUU ############################################

########################################################################################################################################
############## this GiBUU file (GiBUU_2021.root) has been simulated using the flux from GiBUU website ################

f_1 = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/Histogram_for_nue_shweta_5th_update.root","READ")
c1 = ROOT.TCanvas("Canvas1","plot 1")
#c1.Print("plots.pdf[")
c1.SetGrid()

tree_gibuu = f_1.Get("Reco_WCE")
scale_gibuu = 100  
tree_gibuu.Scale(1/scale_gibuu)


T = (5.127*(10**31))      # number of target nucleons

# look for number of target nucleons and phi_total for electron neutrino

value_bin_1_gibuu = tree_gibuu.GetBinContent(1)
value_bin_2_gibuu = tree_gibuu.GetBinContent(2)
value_bin_3_gibuu = tree_gibuu.GetBinContent(3)
value_bin_4_gibuu = tree_gibuu.GetBinContent(4)
value_bin_5_gibuu = tree_gibuu.GetBinContent(5)
value_bin_6_gibuu = tree_gibuu.GetBinContent(6)
value_bin_7_gibuu = tree_gibuu.GetBinContent(7)
value_bin_8_gibuu = tree_gibuu.GetBinContent(8)
value_bin_9_gibuu = tree_gibuu.GetBinContent(9)
value_bin_10_gibuu = tree_gibuu.GetBinContent(10)
value_bin_11_gibuu = tree_gibuu.GetBinContent(11)
value_bin_12_gibuu = tree_gibuu.GetBinContent(12)
value_bin_13_gibuu = tree_gibuu.GetBinContent(13)
value_bin_14_gibuu = tree_gibuu.GetBinContent(14)
value_bin_15_gibuu = tree_gibuu.GetBinContent(15)
value_bin_16_gibuu = tree_gibuu.GetBinContent(16)
value_bin_17_gibuu = tree_gibuu.GetBinContent(17)
value_bin_18_gibuu = tree_gibuu.GetBinContent(18)
value_bin_19_gibuu = tree_gibuu.GetBinContent(19)
value_bin_20_gibuu = tree_gibuu.GetBinContent(20)
value_bin_21_gibuu = tree_gibuu.GetBinContent(21)
value_bin_22_gibuu = tree_gibuu.GetBinContent(22)
value_bin_23_gibuu = tree_gibuu.GetBinContent(23)
value_bin_24_gibuu = tree_gibuu.GetBinContent(24)
value_bin_25_gibuu = tree_gibuu.GetBinContent(25)
value_bin_26_gibuu = tree_gibuu.GetBinContent(26)


reco_wc_cross_section_gibuu = np.array([value_bin_1_gibuu,value_bin_2_gibuu,value_bin_3_gibuu,value_bin_4_gibuu,value_bin_5_gibuu,value_bin_6_gibuu,value_bin_7_gibuu,value_bin_8_gibuu,value_bin_9_gibuu,value_bin_10_gibuu,value_bin_11_gibuu,value_bin_12_gibuu,value_bin_13_gibuu,value_bin_14_gibuu,value_bin_15_gibuu,value_bin_16_gibuu,value_bin_17_gibuu,value_bin_18_gibuu,value_bin_19_gibuu,value_bin_20_gibuu,value_bin_21_gibuu,value_bin_22_gibuu,value_bin_23_gibuu,value_bin_24_gibuu,value_bin_25_gibuu,value_bin_26_gibuu])
reco_event_no_gibuu = reco_wc_cross_section_gibuu*T*nue_flux 
reco_event_no_gibuu_prime = np.divide(reco_event_no_gibuu,1.57)

#########################################################################################################################################

########################### wire cell cross section per unit mean energy through GIBUU reweighting ############################################

#########################################################################################################################################

f_1_rw = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/Histogram_for_nue_shweta_5th_update.root","READ")
c1 = ROOT.TCanvas("Canvas1","plot 1")
#c1.Print("plots.pdf[")
c1.SetGrid()

tree_gibuu_rw = f_1_rw.Get("Reco_WCE_rwt")
scale_gibuu_rw = 100  
tree_gibuu_rw.Scale(1/scale_gibuu_rw)



value_bin_1_gibuu_rw = tree_gibuu_rw.GetBinContent(1)
value_bin_2_gibuu_rw = tree_gibuu_rw.GetBinContent(2)
value_bin_3_gibuu_rw = tree_gibuu_rw.GetBinContent(3)
value_bin_4_gibuu_rw = tree_gibuu_rw.GetBinContent(4)
value_bin_5_gibuu_rw = tree_gibuu_rw.GetBinContent(5)
value_bin_6_gibuu_rw = tree_gibuu_rw.GetBinContent(6)
value_bin_7_gibuu_rw = tree_gibuu_rw.GetBinContent(7)
value_bin_8_gibuu_rw = tree_gibuu_rw.GetBinContent(8)
value_bin_9_gibuu_rw = tree_gibuu_rw.GetBinContent(9)
value_bin_10_gibuu_rw = tree_gibuu_rw.GetBinContent(10)
value_bin_11_gibuu_rw = tree_gibuu_rw.GetBinContent(11)
value_bin_12_gibuu_rw = tree_gibuu_rw.GetBinContent(12)
value_bin_13_gibuu_rw = tree_gibuu_rw.GetBinContent(13)
value_bin_14_gibuu_rw = tree_gibuu_rw.GetBinContent(14)
value_bin_15_gibuu_rw = tree_gibuu_rw.GetBinContent(15)
value_bin_16_gibuu_rw = tree_gibuu_rw.GetBinContent(16)
value_bin_17_gibuu_rw = tree_gibuu_rw.GetBinContent(17)
value_bin_18_gibuu_rw = tree_gibuu_rw.GetBinContent(18)
value_bin_19_gibuu_rw = tree_gibuu_rw.GetBinContent(19)
value_bin_20_gibuu_rw = tree_gibuu_rw.GetBinContent(20)
value_bin_21_gibuu_rw = tree_gibuu_rw.GetBinContent(21)
value_bin_22_gibuu_rw = tree_gibuu_rw.GetBinContent(22)
value_bin_23_gibuu_rw = tree_gibuu_rw.GetBinContent(23)
value_bin_24_gibuu_rw = tree_gibuu_rw.GetBinContent(24)
value_bin_25_gibuu_rw = tree_gibuu_rw.GetBinContent(25)
value_bin_26_gibuu_rw = tree_gibuu_rw.GetBinContent(26)

reco_wc_cross_section_gibuu_rw = np.array([value_bin_1_gibuu_rw,value_bin_2_gibuu_rw,value_bin_3_gibuu_rw,value_bin_4_gibuu_rw,value_bin_5_gibuu_rw,value_bin_6_gibuu_rw,value_bin_7_gibuu_rw,value_bin_8_gibuu_rw,value_bin_9_gibuu_rw,value_bin_10_gibuu_rw,value_bin_11_gibuu_rw,value_bin_12_gibuu_rw,value_bin_13_gibuu_rw,value_bin_14_gibuu_rw,value_bin_15_gibuu_rw,value_bin_16_gibuu_rw,value_bin_17_gibuu_rw,value_bin_18_gibuu_rw,value_bin_19_gibuu_rw,value_bin_20_gibuu_rw,value_bin_21_gibuu_rw,value_bin_22_gibuu_rw,value_bin_23_gibuu_rw,value_bin_24_gibuu_rw,value_bin_25_gibuu_rw,value_bin_26_gibuu_rw])
reco_event_no_gibuu_rw = reco_wc_cross_section_gibuu_rw*T*nue_flux
reco_event_no_gibuu_rw_prime = np.divide(reco_event_no_gibuu_rw,1.57)


#########################################################################################################################################

########################### wire cell cross section per unit mean energy using GENIE ############################################

#########################################################################################################################################



f_3 = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/analysis_nueGENIErw_new.root","READ")

tree_1_genie = f_3.Get("EnuWC_CCQE_GENIE")
tree_2_genie = f_3.Get("EnuWC_CCMEC_GENIE")
tree_3_genie = f_3.Get("EnuWC_CCRES_GENIE")
tree_4_genie = f_3.Get("EnuWC_CCDIS_GENIE")
tree_5_genie = f_3.Get("EnuWC_CCCOH_GENIE")

tree_genie = tree_1_genie + tree_2_genie + tree_3_genie + tree_4_genie + tree_5_genie
scale_genie = 100
#scale_genie = 100 * (4.84*(10**31))
tree_genie.Scale(1/scale_genie)


value_bin_1_genie = tree_genie.GetBinContent(1)
value_bin_2_genie = tree_genie.GetBinContent(2)
value_bin_3_genie = tree_genie.GetBinContent(3)
value_bin_4_genie = tree_genie.GetBinContent(4)
value_bin_5_genie = tree_genie.GetBinContent(5)
value_bin_6_genie = tree_genie.GetBinContent(6)
value_bin_7_genie = tree_genie.GetBinContent(7)
value_bin_8_genie = tree_genie.GetBinContent(8)
value_bin_9_genie = tree_genie.GetBinContent(9)
value_bin_10_genie = tree_genie.GetBinContent(10)
value_bin_11_genie = tree_genie.GetBinContent(11)
value_bin_12_genie = tree_genie.GetBinContent(12)
value_bin_13_genie = tree_genie.GetBinContent(13)
value_bin_14_genie = tree_genie.GetBinContent(14)
value_bin_15_genie = tree_genie.GetBinContent(15)
value_bin_16_genie = tree_genie.GetBinContent(16)
value_bin_17_genie = tree_genie.GetBinContent(17)
value_bin_18_genie = tree_genie.GetBinContent(18)
value_bin_19_genie = tree_genie.GetBinContent(19)
value_bin_20_genie = tree_genie.GetBinContent(20)
value_bin_21_genie = tree_genie.GetBinContent(21)
value_bin_22_genie = tree_genie.GetBinContent(22)
value_bin_23_genie = tree_genie.GetBinContent(23)
value_bin_24_genie = tree_genie.GetBinContent(24)
value_bin_25_genie = tree_genie.GetBinContent(25)
value_bin_26_genie = tree_genie.GetBinContent(26)


reco_event_no_genie= np.array([value_bin_1_genie,value_bin_2_genie,value_bin_3_genie,value_bin_4_genie,value_bin_5_genie,value_bin_6_genie,value_bin_7_genie,value_bin_8_genie,value_bin_9_genie,value_bin_10_genie,value_bin_11_genie,value_bin_12_genie,value_bin_13_genie,value_bin_14_genie,value_bin_15_genie,value_bin_16_genie,value_bin_17_genie,value_bin_18_genie,value_bin_19_genie,value_bin_20_genie,value_bin_21_genie,value_bin_22_genie,value_bin_23_genie,value_bin_24_genie,value_bin_25_genie,value_bin_26_genie])
reco_event_no_genie_prime = np.divide(reco_event_no_genie,1.57)
reco_event_no_genie_prime_eff_correction = reco_event_no_genie_prime * 0.46   # 0.46 is because efficiency is 46%, meaning 46/100

######## efficiency correction obtained from MicroBooNE nue paper plot ############################################################

nue_eff_data = np.array([0.0347,0.1345,0.1974,0.2560,0.3232,0.3688,0.4035,0.4338,0.4490,0.4642,0.4837,0.4902,0.5054,0.4989,0.5119,0.5054,0.5271,0.5076,0.5076,0.5119,0.5054,0.5076,0.5011,0.5098,0.4967,0.4967])
reco_event_no_genie_prime_per_bin_eff_correction = np.multiply(reco_event_no_genie_prime, nue_eff_data)

########################################################################################################################################

#############################        MICROBOONE DATA          #############################################################################

########################################################################################################################################



# x represents the energy along x axis
x_1=[0.00,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1.00,1.10,1.20,1.30,1.40,1.50,1.60,1.70,1.80,1.90,2.00,2.10,2.20,2.30,2.40,2.50,2.60]
x=np.divide((x_1[0]+x_1[1], x_1[1]+x_1[2], x_1[2]+x_1[3], x_1[3]+x_1[4], x_1[4]+x_1[5], x_1[5]+x_1[6], x_1[6]+x_1[7], x_1[7]+x_1[8], x_1[8]+x_1[9], x_1[9]+x_1[10], x_1[10]+x_1[11], x_1[11]+x_1[12], x_1[12]+x_1[13], x_1[13]+x_1[14], x_1[14]+x_1[15], x_1[15]+x_1[16], x_1[16]+x_1[17], x_1[17]+x_1[18], x_1[18]+x_1[19], x_1[19]+x_1[20], x_1[20]+x_1[21], x_1[21]+x_1[22], x_1[22]+x_1[23], x_1[23]+x_1[24], x_1[24]+x_1[25], x_1[25]+x_1[26]), 2.0)

Width = [x_1[1]-x_1[0],x_1[2]-x_1[1],x_1[3]-x_1[2],x_1[4]-x_1[3],x_1[5]-x_1[4],x_1[6]-x_1[5],x_1[7]-x_1[6],x_1[8]-x_1[7],x_1[9]-x_1[8],x_1[10]-x_1[9],x_1[11]-x_1[10],x_1[12]-x_1[11],x_1[13]-x_1[12],x_1[14]-x_1[13],x_1[15]-x_1[14],x_1[16]-x_1[15],x_1[17]-x_1[16],x_1[18]-x_1[17],x_1[19]-x_1[18],x_1[20]-x_1[19],x_1[21]-x_1[20],x_1[22]-x_1[21],x_1[23]-x_1[22],x_1[24]-x_1[23],x_1[25]-x_1[24],x_1[26]-x_1[25]]
x_error_prime = np.divide(Width, 2.0)


# y_1 represents microboone data (number of events)
y_1 = np.array([0,5,6, 12,19,14,18,24,25,22,29,18,16,18,15,20,12,13,9,5,9,10,4,7,8,30])

plt.plot(x, y_1, "*", color = 'black')
plt.plot(x, reco_event_no_gibuu_prime*(10**(-38)), "*-", color = 'darkorange')
plt.plot(x, reco_event_no_gibuu_rw_prime*(10**(-38)), "*-", color = 'red')
plt.plot(x, reco_event_no_genie_prime, "*-", color = 'blue')
plt.plot(x, reco_event_no_genie_prime_per_bin_eff_correction, "*-", color = 'green')
#plt.plot(x, reco_event_no_genie_prime_eff_correction, "*-", color = 'g')
#plt.bar(x, reco_event_no_gibuu, width = Width, edgecolor='blue', color='None', align = 'edge')
#plt.errorbar(x_centre, y, yerr=y_error, xerr = asymmetric_error, fmt = ' ', ecolor = 'black', elinewidth=1, capsize=5,
#capthick=1, barsabove=False )
#plt.ylim([0, 36])
#plt.xlim([0, 2.5])



plt.title('data MC comparision')
plt.xlabel('$E_\\nu \; (GeV)$')
#plt.ylabel('$\sigma(E_\\nu) / <E_\\nu>$  ($10^{-38} {cm}^2/GeV/ \, n $)')
plt.ylabel('event count per bin')
#plt.gca().legend(('microboone data','GENIE','GENIE (eff bin by bin)'))
plt.gca().legend(('microboone data','GIBUU 2021','GIBUU RW 2021','GENIE','GENIE (eff bin by bin)'))
#plt.gca().legend(('microboone data','GIBUU 2021','GIBUU RW 2021','GENIE','GENIE (46% eff correction)'))
#plt.gca().legend(('microboone data','GIBUU 2021 (GW)','GIBUU RW 2021 (GW)'))
plt.show()
#######################################################################################################################################
# Out:
# Welcome to JupyROOT 6.24/06
# 4205000644.4441776
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas1
