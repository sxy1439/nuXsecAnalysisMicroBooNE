# %%
#####################################################################################################################################

####################### final muon wire cell #####################################################################################

#####################################################################################################################################

import ROOT
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
import math
import scipy.stats as stats

########################################################################################################################################

########################### true wire cell cross section per unit mean energy through GIBUU ############################################

########################################################################################################################################
############## this GiBUU file (GiBUU.root) has been simulated using the Steven Gardiner flux #######################



f_1 = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/out_microB_xsec_GiBUU.root","READ")
c1 = ROOT.TCanvas("Canvas1","plot 1")
#c1.Print("plots.pdf[")
c1.SetGrid()

tree_gibuu = f_1.Get("TrueEnu_CC_GiBUU")
scale_gibuu = 100  
tree_gibuu.Scale(1/scale_gibuu)

########################### Steven Gardiner flux (~ 1x10^21 POT) ################################################################

phi_total = (5.85028*(10**9)) 
phi_1 = (1.49786*(10**9))
phi_2 = (8.22204*(10**8))
phi_3 = (4.8028*(10**8))
phi_4 = (5.10686*(10**8))
phi_5 = (5.12131*(10**8))
phi_6 = (4.93841*(10**8))
phi_7 = (4.41834*(10**8))
phi_8 = (3.21304*(10**8))
phi_9 = (2.85655*(10**8))
phi_10 = (8.8162*(10**7)) 




#a1 = 1.268*(10**9) 
#b1 = 0.4565
#c1 = 0.2151
#a2 = 2.949*(10**8)
#b2 = 0.7237
#c2 = 0.1091
#a3 = 8.114*(10**8)
#b3 = 0.2216
#c3 = 0.1228
#a4 = 1.541*(10**8)
#b4 = 0.8688
#c4 = 0.1286
#a5 = 4.222*(10**9)
#b5 =  0.7346
#c5 = 0.7332

    
#def f(x):
#    return a1*math.exp(-((x-b1)/c1)**2) + a2*math.exp(-((x-b2)/c2)**2) + a3*math.exp(-((x-b3)/c3)**2) + a4*math.exp(-((x-b4)/c4)**2) + a5*math.exp(-((x-b5)/c5)**2)  
#x = sy.Symbol("x")
#sy.integrate(f(x), (x, 0.2, 0.54))


#phi_total = ((0.492544+1.89066+2.44421+2.91236+3.61745+3.98637+4.26238+4.46389+4.72023+4.92222+5.03407+5.04208+4.97703+4.92587+4.8751+4.76129+4.58316+4.39217+4.20125+3.97732+3.77124+3.53281+3.28751+3.0546+2.83217+2.57803+2.34652+2.10236+1.85976+1.62091+1.41211+1.21925+1.0362+0.87352+0.738243+0.611492+0.507337+0.410277+0.334644+0.270411+0.215836+0.176473+0.145358+0.11527+0.0990896+0.0852773+0.0738661+0.0644309+0.0585384+0.053078+0.0490472+0.0460699+0.0442574+0.0428918+0.0411151+0.0382788+0.0377446+0.0365919+0.0358925+0.0334044+0.032049+0.0310074+0.031785+0.0297035+0.0287819+0.0281035+0.0267015+0.02655811+0.255155+0.0248278+0.0244332+0.0228545+0.0221971+0.021078+0.0206122+0.0200581+0.0181843+0.0174887+0.0166799+0.0164523)*(10**9)) 
#phi_1 = ((3.61745+3.98637+4.26238+4.46389+4.72023+4.92222+5.03407)*(10**9))
#phi_2 = ((5.04208+4.97703+4.92587)*(10**9))
#phi_3 = ((4.8751+4.76129+4.58316)*(10**9))
#phi_4 = ((4.58316+4.39217+4.20125)*(10**9))
#phi_5 = ((3.97732+3.77124)*(10**9))
#phi_6 = ((3.53281+3.28751+3.0546)*(10**9))
#phi_7 = ((2.83217+2.57803+2.34652)*(10**9))
#phi_8 = ((2.10236+1.85976+1.62091+1.41211)*(10**9))
#phi_9 = ((1.21925+1.0362+0.87352+0.738243+0.611492+0.507337+0.410277+0.334644+0.270411+0.215836)*(10**9))
#phi_10 = ((0.176473+0.145358+0.11527+0.0990896+0.0852773+0.0738661+0.0644309+0.0585384+0.053078+0.0460699+0.0442574+0.0428918+0.0411151+0.0382788+0.0377446+0.0365919+0.0358925+0.0334044+0.032049+0.0310074+0.031785+0.0297035+0.0287819+0.0281035+0.0267015+0.02655811+0.255155+0.0248278+0.0244332+0.0228545+0.0221971+0.021078+0.0206122+0.0200581+0.0181843+0.0174887+0.0166799+0.0164523)*(10**9)) 


eff_si_1 = np.divide(phi_1,phi_total)
eff_si_2 = np.divide(phi_2,phi_total)
eff_si_3 = np.divide(phi_3,phi_total)
eff_si_4 = np.divide(phi_4,phi_total)
eff_si_5 = np.divide(phi_5,phi_total)
eff_si_6 = np.divide(phi_6,phi_total)
eff_si_7 = np.divide(phi_7,phi_total)
eff_si_8 = np.divide(phi_8,phi_total)
eff_si_9 = np.divide(phi_9,phi_total)
eff_si_10 = np.divide(phi_10,phi_total)



value_bin_1_gibuu = tree_gibuu.GetBinContent(1)
value_bin_1_gibuu_prime = np.divide(value_bin_1_gibuu,eff_si_1)
value_bin_2_gibuu = tree_gibuu.GetBinContent(2)
value_bin_2_gibuu_prime = np.divide(value_bin_2_gibuu,eff_si_2)
value_bin_3_gibuu = tree_gibuu.GetBinContent(3)
value_bin_3_gibuu_prime = np.divide(value_bin_3_gibuu,eff_si_3)
value_bin_4_gibuu = tree_gibuu.GetBinContent(4)
value_bin_4_gibuu_prime = np.divide(value_bin_4_gibuu,eff_si_4)
value_bin_5_gibuu = tree_gibuu.GetBinContent(5)
value_bin_5_gibuu_prime = np.divide(value_bin_5_gibuu,eff_si_5)
value_bin_6_gibuu = tree_gibuu.GetBinContent(6)
value_bin_6_gibuu_prime = np.divide(value_bin_6_gibuu,eff_si_6)
value_bin_7_gibuu = tree_gibuu.GetBinContent(7)
value_bin_7_gibuu_prime = np.divide(value_bin_7_gibuu,eff_si_7)
value_bin_8_gibuu = tree_gibuu.GetBinContent(8)
value_bin_8_gibuu_prime = np.divide(value_bin_8_gibuu,eff_si_8)
value_bin_9_gibuu = tree_gibuu.GetBinContent(9)
value_bin_9_gibuu_prime = np.divide(value_bin_9_gibuu,eff_si_9)
value_bin_10_gibuu = tree_gibuu.GetBinContent(10)
value_bin_10_gibuu_prime = np.divide(value_bin_10_gibuu,eff_si_10)


true_wc_cross_section_gibuu = np.array([value_bin_1_gibuu_prime,value_bin_2_gibuu_prime,value_bin_3_gibuu_prime,value_bin_4_gibuu_prime,value_bin_5_gibuu_prime,value_bin_6_gibuu_prime,value_bin_7_gibuu_prime,value_bin_8_gibuu_prime,value_bin_9_gibuu_prime,value_bin_10_gibuu_prime])
print("true_wc_cross_section \n", true_wc_cross_section_gibuu)

#########################################################################################################################################

########################### true wire cell cross section per unit mean energy through GIBUU reweighting ############################################

#########################################################################################################################################

#f_1_rw = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/GIBUU_rw_wc.root","READ")
f_1_rw = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/very_last_one.root","READ")
c1 = ROOT.TCanvas("Canvas1","plot 1")
#c1.Print("plots.pdf[")
c1.SetGrid()

tree_gibuu_rw = f_1_rw.Get("TrueEnu_Reweighted")
scale_gibuu_rw = 100  
tree_gibuu_rw.Scale(1/scale_gibuu_rw)



value_bin_1_gibuu_rw = tree_gibuu_rw.GetBinContent(1)
value_bin_1_gibuu_prime_rw = np.divide(value_bin_1_gibuu_rw,eff_si_1)
value_bin_2_gibuu_rw = tree_gibuu_rw.GetBinContent(2)
value_bin_2_gibuu_prime_rw = np.divide(value_bin_2_gibuu_rw,eff_si_2)
value_bin_3_gibuu_rw = tree_gibuu_rw.GetBinContent(3)
value_bin_3_gibuu_prime_rw = np.divide(value_bin_3_gibuu_rw,eff_si_3)
value_bin_4_gibuu_rw = tree_gibuu_rw.GetBinContent(4)
value_bin_4_gibuu_prime_rw = np.divide(value_bin_4_gibuu_rw,eff_si_4)
value_bin_5_gibuu_rw = tree_gibuu_rw.GetBinContent(5)
value_bin_5_gibuu_prime_rw = np.divide(value_bin_5_gibuu_rw,eff_si_5)
value_bin_6_gibuu_rw = tree_gibuu_rw.GetBinContent(6)
value_bin_6_gibuu_prime_rw = np.divide(value_bin_6_gibuu_rw,eff_si_6)
value_bin_7_gibuu_rw = tree_gibuu_rw.GetBinContent(7)
value_bin_7_gibuu_prime_rw = np.divide(value_bin_7_gibuu_rw,eff_si_7)
value_bin_8_gibuu_rw = tree_gibuu_rw.GetBinContent(8)
value_bin_8_gibuu_prime_rw = np.divide(value_bin_8_gibuu_rw,eff_si_8)
value_bin_9_gibuu_rw = tree_gibuu_rw.GetBinContent(9)
value_bin_9_gibuu_prime_rw = np.divide(value_bin_9_gibuu_rw,eff_si_9)
value_bin_10_gibuu_rw = tree_gibuu_rw.GetBinContent(10)
value_bin_10_gibuu_prime_rw = np.divide(value_bin_10_gibuu_rw,eff_si_10)

#tree_gibuu_rw.Draw('HIST','same')
#c1.Draw()

true_wc_cross_section_gibuu_rw = np.array([value_bin_1_gibuu_prime_rw,value_bin_2_gibuu_prime_rw,value_bin_3_gibuu_prime_rw,value_bin_4_gibuu_prime_rw,value_bin_5_gibuu_prime_rw,value_bin_6_gibuu_prime_rw,value_bin_7_gibuu_prime_rw,value_bin_8_gibuu_prime_rw,value_bin_9_gibuu_prime_rw,value_bin_10_gibuu_prime_rw])
print("true_wc_cross_section \n", true_wc_cross_section_gibuu_rw)



#################### smearing matrix ####################################################################################################

f_2 = open ( '/Users/sxy1439/Documents/sbnd/workarea/wire_smearing_matrix.txt' , 'r')
wire_cell_smearing = []
wire_cell_smearing = np.array([ line.split() for line in f_2], dtype = np.float64)     # .float64 is used to convert the data from scientific form (example, E-02) to float

print("wire cell smearing matrix \n \n", wire_cell_smearing)



##################### true cross section after smearing through GIBUU ##################################################################################


#reconstructed_wc_cross_section = np.dot(wire_cell_smearing,true_wc_cross_section)  
#print("reconstructed_wc_cross_section ", reconstructed_wc_cross_section)

# both np.dot and np.matmul does the matrix multiplication of 2d array but matmul is preferred

true_wc_cross_after_smearing_gibuu = np.matmul(wire_cell_smearing,true_wc_cross_section_gibuu)  
#print("GIBUU true_wc_cross_after_smearing \n", true_wc_cross_after_smearing_gibuu)

##################### true cross section after smearing through GIBUU reweighted ##################################################################################


#reconstructed_wc_cross_section = np.dot(wire_cell_smearing,true_wc_cross_section)  
#print("reconstructed_wc_cross_section ", reconstructed_wc_cross_section)

# both np.dot and np.matmul does the matrix multiplication of 2d array but matmul is preferred

true_wc_cross_after_smearing_gibuu_rw = np.matmul(wire_cell_smearing,true_wc_cross_section_gibuu_rw)  
#print("reweighted GIBUU true_wc_cross_after_smearing \n", true_wc_cross_after_smearing_gibuu_rw)




########################################################################################################################################

########################### true wire cell cross section per unit mean energy through GENIE ############################################

########################################################################################################################################


f_3 = ROOT.TFile.Open("/Users/sxy1439/Documents/sbnd/workarea/analysis_numuGENIErw_new.root","READ")

tree_1_genie = f_3.Get("TrueEnu_CCQE_GENIE")
tree_2_genie = f_3.Get("TrueEnu_CCMEC_GENIE")
tree_3_genie = f_3.Get("TrueEnu_CCRES_GENIE")
tree_4_genie = f_3.Get("TrueEnu_CCDIS_GENIE")
tree_5_genie = f_3.Get("TrueEnu_CCCOH_GENIE")

tree_genie = tree_1_genie + tree_2_genie + tree_3_genie + tree_4_genie + tree_5_genie
scale_genie = 100 * (5.127*(10**31))  #(5.127*(10**31)) is the number of target nucleons
#scale_genie = 100 * (1.21*(10**30))
scale_genie = 100 * (4.84*(10**31))
tree_genie.Scale(1/scale_genie)


value_bin_1_genie = tree_genie.GetBinContent(1)
value_bin_1_genie_prime = np.divide(value_bin_1_genie,phi_1)
value_bin_2_genie = tree_genie.GetBinContent(2)
value_bin_2_genie_prime = np.divide(value_bin_2_genie,phi_2)
value_bin_3_genie = tree_genie.GetBinContent(3)
value_bin_3_genie_prime = np.divide(value_bin_3_genie,phi_3)
value_bin_4_genie = tree_genie.GetBinContent(4)
value_bin_4_genie_prime = np.divide(value_bin_4_genie,phi_4)
value_bin_5_genie = tree_genie.GetBinContent(5)
value_bin_5_genie_prime = np.divide(value_bin_5_genie,phi_5)
value_bin_6_genie = tree_genie.GetBinContent(6)
value_bin_6_genie_prime = np.divide(value_bin_6_genie,phi_6)
value_bin_7_genie = tree_genie.GetBinContent(7)
value_bin_7_genie_prime = np.divide(value_bin_7_genie,phi_7)
value_bin_8_genie = tree_genie.GetBinContent(8)
value_bin_8_genie_prime = np.divide(value_bin_8_genie,phi_8)
value_bin_9_genie = tree_genie.GetBinContent(9)
value_bin_9_genie_prime = np.divide(value_bin_9_genie,phi_9)
value_bin_10_genie = tree_genie.GetBinContent(10)
value_bin_10_genie_prime = np.divide(value_bin_10_genie,phi_10)



true_wc_cross_section_genie = np.array([value_bin_1_genie_prime,value_bin_2_genie_prime,value_bin_3_genie_prime,value_bin_4_genie_prime,value_bin_5_genie_prime,value_bin_6_genie_prime,value_bin_7_genie_prime,value_bin_8_genie_prime,value_bin_9_genie_prime,value_bin_10_genie_prime])
#print("true_wc_cross_section_genie \n", true_wc_cross_section_genie)


##################### true cross section after smearing through GENIE ##################################################################################


# both np.dot and np.matmul does the matrix multiplication of 2d array but matmul is preferred

true_wc_cross_after_smearing_genie = np.matmul(wire_cell_smearing,true_wc_cross_section_genie)  
print("true_genie_wc_cross_after_smearing \n", true_wc_cross_after_smearing_genie)



########################################################################################################################################

#############################        MICROBOONE DATA          #############################################################################

########################################################################################################################################



# x represents the energy along x axis
x_1=[0.2,0.54,0.705,0.805,0.92,1.05,1.2,1.375,1.57,2.05,4.0]
x=np.divide((x_1[0]+x_1[1], x_1[1]+x_1[2], x_1[2]+x_1[3], x_1[3]+x_1[4], x_1[4]+x_1[5], x_1[5]+x_1[6], x_1[6]+x_1[7], x_1[7]+x_1[8], x_1[8]+x_1[9], x_1[9]+x_1[10]), 2.0)

x_centre = np.array((0.3818, 0.622, 0.7546, 0.8615, 0.9833, 1.122, 1.282, 1.463, 1.735, 2.619))

Width_1 = [x_centre[0]-0,x_centre[1]-x_centre[0],x_centre[2]-x_centre[1],x_centre[3]-x_centre[2],x_centre[4]-x_centre[3],x_centre[5]-x_centre[4],x_centre[6]-x_centre[5],x_centre[7]-x_centre[6],x_centre[8]-x_centre[7],x_centre[9]-x_centre[8]]
Width = [x_1[1]-x_1[0],x_1[2]-x_1[1],x_1[3]-x_1[2],x_1[4]-x_1[3],x_1[5]-x_1[4],x_1[6]-x_1[5],x_1[7]-x_1[6],x_1[8]-x_1[7],x_1[9]-x_1[8],x_1[10]-x_1[9]]
x_error_prime = np.divide(Width, 2.0)
x_error = np.divide(x_error_prime,x_centre)

# y_1 represents microboone data of cross section per unit energy
y_1 = np.array([0.3367, 0.6751, 0.9309, 1.092, 1.192, 1.234, 1.292, 1.401, 1.571, 1.977])
y = np.divide(y_1, x_centre)
#print("y value", y)
y_error_prime = [0.04369, 0.06562, 0.08193, 0.08613, 0.09354, 0.1199, 0.1394, 0.1877, 0.2641, 0.378]
y_error = np.divide(y_error_prime, x_centre)

######################### true GIBUU cross section per unit mean energy ##############################################################

y_wc_gibuu = np.divide(true_wc_cross_after_smearing_gibuu, x_centre)
print("cross section per unit mean energy from gibuu \n", y_wc_gibuu)

######################### true reweighted GIBUU cross section per unit mean energy ##############################################################

y_wc_gibuu_rw = np.divide(true_wc_cross_after_smearing_gibuu_rw, x_centre)
print("cross section per unit mean energy from gibuu reweighted \n", y_wc_gibuu_rw)

######################### true GENIE cross section per unit mean energy ##############################################################

y_wc_genie = np.divide(true_wc_cross_after_smearing_genie, x_centre)
y_wc_genie_prime = np.divide(y_wc_genie,18.86)      
### this factor of 18.86 is due to the different flux used by MicroBooNE collaboration paper and Steven Gardiner.
# Here the factor of 18.86 is from np.divide(Steven Gardiner flux(~1x10^21), MicroBooNE flux(5.3x10^19))
print("cross section per unit mean energy from genie \n", y_wc_genie)

#######################################################################################################################################

################################################ PLOTS  ###############################################################################

lower_error = np.array([0.2,0.54,0.705,0.805,0.92,1.05,1.2,1.375,1.57,2.05])
upper_error = np.array([0.54,0.705,0.805,0.92,1.05,1.2,1.375,1.57,2.05,4.0])
asymmetric_error = [x_centre-lower_error, upper_error-x_centre]

plt.plot(x_centre, y, "*", color = 'black')
plt.plot(x_centre, y_wc_gibuu, "*-", color = 'darkorange')
plt.plot(x_centre, y_wc_gibuu_rw, "*-", color = 'red')
plt.plot(x_centre, y_wc_genie_prime*(10**(38)), "*-", color = 'blue')
#plt.plot(x_centre, y_wc_genie*(10**(36)), "*-", color = 'g')
plt.errorbar(x_centre, y, yerr=y_error, xerr = asymmetric_error, fmt = ' ', ecolor = 'black', elinewidth=1, capsize=5,
capthick=1, barsabove=False )
plt.ylim([0, 2])
plt.xlim([0, 4])
#plt.bar(x_1_GIBUU_wc, y_1_GIBUU_wc, width = Width, edgecolor='blue', color='none', align = 'edge')

#plt.errorbar(x, y_1_GIBUU_wc, yerr=None, xerr = x_error, fmt = ' ', ecolor = 'blue', elinewidth=1, capsize=5,
#capthick=1, barsabove=False )


plt.title('data MC comparision')
plt.xlabel('$E_\\nu \; (GeV)$')
#plt.ylabel('$\sigma(E_\\nu) / <E_\\nu>$  ($10^{-38} {cm}^2/GeV/ \, n $)')
plt.ylabel('$\sigma(E_\\nu) / <E_\\nu>$  ($10^{-38} {cm}^2/GeV/ \, n $)')
plt.gca().legend(('microboone data','GIBUU 2021 (SG)','GIBUU RW 2021 (SG)','GENIE(dividing by a factor of 18.86)'))
#plt.gca().legend(('microboone data','GIBUU 2022','GIBUU RW 2022','GENIE(divided by a factor of 16)'))
plt.show()
#######################################################################################################################################
tree_gibuu.Draw('HIST')
tree_genie.Draw('HIST, same')
c1.Draw()



########################################################################################################################################

################################# chi square test ######################### GIBUU ####################################

########################################################################################################################################
# covariance matrix extracted from "https://arxiv.org/src/2110.14023v2/anc/microboone_cc_inclusive_cov_mat.txt" 
#in the form of n dimensional array (or a matrix)


f = open ( '/Users/sxy1439/Documents/sbnd/workarea/cov_matrix_wire_cell.txt' , 'r')
cov_matrix_wc_gibuu = []
cov_matrix_wc_gibuu = np.array([ line.split() for line in f], dtype = np.float64)     # .float64 is used to convert the data from scientific form (example, E-02) to float
inverse_cov_matrix_wc_gibuu = np.linalg.inv(cov_matrix_wc_gibuu)            # .linalg.inv() is used to take the inverse of a matrix

#print("covariance matrix \n \n", cov_matrix_wc)
print ("inverse of the covariance matrix \n \n", inverse_cov_matrix_wc_gibuu)
#type(covariance_matrix)
cov_matrix_wc_gibuu.dtype.name
cov_matrix_wc_gibuu.shape
cov_matrix_wc_gibuu.T.shape


observed_gibuu = np.array(true_wc_cross_after_smearing_gibuu)
expected_gibuu = np.array(y_1)

del_x_gibuu = np.array([observed_gibuu - expected_gibuu])
#print("the difference in observed and expected data \n", del_x)
del_x_gibuu.shape

del_x_transpose_gibuu = np.array(del_x_gibuu.T)      # .T is used for getting the transpose of a matrix
#print(del_x_transpose)
del_x_transpose_gibuu.shape

initiate_chi2_value_gibuu = np.dot(inverse_cov_matrix_wc_gibuu, del_x_transpose_gibuu)    #np.dot does the matrix multiplication
chi2_value_gibuu = np.dot(del_x_gibuu, initiate_chi2_value_gibuu)
print("the chi square value from our analysis for GiBUU using wire cell method is :", chi2_value_gibuu)

########################################################################################################################################

################################# chi square test ######################### GIBUU reweighted ####################################

########################################################################################################################################
# covariance matrix extracted from "https://arxiv.org/src/2110.14023v2/anc/microboone_cc_inclusive_cov_mat.txt" 
#in the form of n dimensional array (or a matrix)

f = open ( '/Users/sxy1439/Documents/sbnd/workarea/cov_matrix_wire_cell.txt' , 'r')
cov_matrix_wc_gibuu_rw = []
cov_matrix_wc_gibuu_rw = np.array([ line.split() for line in f], dtype = np.float64)     # .float64 is used to convert the data from scientific form (example, E-02) to float
inverse_cov_matrix_wc_gibuu_rw = np.linalg.inv(cov_matrix_wc_gibuu_rw)            # .linalg.inv() is used to take the inverse of a matrix

#print("covariance matrix \n \n", cov_matrix_wc)
#print ("inverse of the covariance matrix \n \n", inverse_cov_matrix_wc)
#type(covariance_matrix)
cov_matrix_wc_gibuu_rw.dtype.name
cov_matrix_wc_gibuu_rw.shape
cov_matrix_wc_gibuu_rw.T.shape


observed_gibuu_rw = np.array(true_wc_cross_after_smearing_gibuu_rw)
expected_gibuu_rw = np.array(y_1)

del_x_gibuu_rw = np.array([observed_gibuu_rw - expected_gibuu_rw])
#print("the difference in observed and expected data \n", del_x)
del_x_gibuu_rw.shape

del_x_transpose_gibuu_rw = np.array(del_x_gibuu_rw.T)      # .T is used for getting the transpose of a matrix
#print(del_x_transpose)
del_x_transpose_gibuu_rw.shape

initiate_chi2_value_gibuu_rw = np.dot(inverse_cov_matrix_wc_gibuu_rw, del_x_transpose_gibuu_rw)    #np.dot does the matrix multiplication
chi2_value_gibuu_rw = np.dot(del_x_gibuu_rw, initiate_chi2_value_gibuu_rw)
print("the chi square value from our analysis for GiBUU reweighted using wire cell method is :", chi2_value_gibuu_rw)

########################################################################################################################################

################################# chi square test ######################### GENIE ####################################

########################################################################################################################################
# covariance matrix extracted from "https://arxiv.org/src/2110.14023v2/anc/microboone_cc_inclusive_cov_mat.txt" 
#in the form of n dimensional array (or a matrix)

f = open ( '/Users/sxy1439/Documents/sbnd/workarea/cov_matrix_wire_cell.txt' , 'r')
cov_matrix_wc_genie = []
cov_matrix_wc_genie = np.array([ line.split() for line in f], dtype = np.float64)     # .float64 is used to convert the data from scientific form (example, E-02) to float
inverse_cov_matrix_wc_genie = np.linalg.inv(cov_matrix_wc_gibuu_rw)            # .linalg.inv() is used to take the inverse of a matrix

#print("covariance matrix \n \n", cov_matrix_wc)
#print ("inverse of the covariance matrix \n \n", inverse_cov_matrix_wc_genie)
#type(covariance_matrix)
cov_matrix_wc_genie.dtype.name
cov_matrix_wc_genie.shape
cov_matrix_wc_genie.T.shape

newtrue_wc_cross_after_smearing_genie = np.divide(true_wc_cross_after_smearing_genie,18.86)
observed_genie = np.array(newtrue_wc_cross_after_smearing_genie*(10**(38)))
expected_genie = np.array(y_1)

del_x_genie = np.array([observed_genie - expected_genie])
#print("the difference in observed and expected data \n", del_x)
del_x_genie.shape

del_x_transpose_genie = np.array(del_x_genie.T)      # .T is used for getting the transpose of a matrix
#print(del_x_transpose)
del_x_transpose_genie.shape

initiate_chi2_value_genie = np.dot(inverse_cov_matrix_wc_genie, del_x_transpose_genie)    #np.dot does the matrix multiplication
chi2_value_genie = np.dot(del_x_genie, initiate_chi2_value_genie)
print("the chi square value from our analysis for GENIE using wire cell method is :", chi2_value_genie)
# Out:
# Welcome to JupyROOT 6.24/06
# true_wc_cross_section
#  [0.36873495 0.76105783 0.86998066 0.97469542 1.10648078 1.26728669
#  1.3642807  1.50510879 1.57755759 2.25354791]
# true_wc_cross_section
#  [0.27689897 0.70465773 0.90338636 1.05254446 1.22446505 1.3137378
#  1.34822587 1.47061777 1.6337863  1.97242555]
# wire cell smearing matrix
#
#  [[ 7.7193e-01  1.6067e-01  2.5056e-03 -2.3549e-02 -1.3922e-02  5.3099e-03
#    1.3827e-02  1.3296e-02  1.8587e-03 -1.3563e-02]
#  [ 5.1029e-01  4.6149e-01  1.4382e-01  4.8657e-02  3.5189e-03 -1.2790e-02
#   -1.7596e-02 -1.1689e-02  2.0003e-03  1.7811e-02]
#  [-1.2146e-03  4.8313e-01  3.0137e-01  2.0307e-01  6.7876e-02 -1.5387e-02
#   -3.1367e-02 -1.2405e-02  2.0622e-02  1.2695e-02]
#  [-1.7011e-01  2.7494e-01  2.9489e-01  2.8457e-01  1.7260e-01  7.1278e-02
#    2.3583e-02  8.9150e-03  8.9130e-03 -1.0599e-02]
#  [-1.7679e-02  2.0195e-02  1.3275e-01  2.4059e-01  2.7945e-01  2.3071e-01
#    1.3165e-01  3.7466e-02 -3.1675e-02 -1.6003e-02]
# ...
